# %%
import pandas as pd
df = pd.read_csv("output.csv")

# %%
df
# Out:
#       Name  Age         City  Salary Department   Bonus Age Category
# 0    Alice   24     New York   70000         HR  7000.0        Young
# 1      Bob   27  Los Angeles   80000    Finance  8000.0     Mid-aged
# 2  Charlie   22      Chicago   50000         IT  5000.0        Young
# 3    David   32      Houston   60000  Marketing  6000.0       Senior
# 4      Eva   29      Phoenix   75000    Finance  7500.0     Mid-aged

# %%
df1=pd.read_excel("OOSC Form.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# ...

# %%
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df1=pd.read_excel("OOSC Form.xlsx")

# %%
df1
# Out:
#                                            Unnamed: 0 Unnamed: 1  \
# 0                                                 NaN        NaN
# 1                                                 NaN        NaN
# 2                                                 NaN        NaN
# 3   Village Name:_________________________________...        NaN
# 4                                                 SR#       Name
# 5                                                 NaN        NaN
# 6                                                 NaN        NaN
# 7                                                 NaN        NaN
# 8                                                 NaN        NaN
# 9                                                 NaN        NaN
# 10                                                NaN        NaN
# 11                                                NaN        NaN
# 12                                                NaN        NaN
# ...
